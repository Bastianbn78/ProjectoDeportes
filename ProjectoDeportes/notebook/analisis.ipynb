# %% [markdown]
# # Analisis de Datos Deportivos
# Este notebook contiene el proceso completo de analisis usando las funciones de limpieza y analisis del proyecto.

# %%
import pandas as pd
import sys
import os
from pathlib import Path


sys.path.append(os.path.abspath('..'))

from outputs.src.limpieza import limpiar_deportistas
from outputs.src.analisis import Resumen_datos, Promedio_por_deporte, Deportistas_destacados

# %%
print('=' * 50)
print('CARGANDO DATOS')
print('=' * 50)

base_path = Path('..').resolve()
csv_path = base_path / 'data' / 'deportistas.csv'
df = pd.read_csv(csv_path)

print(f'Archivo: {csv_path}')
print(f'Registros cargados: {len(df)}')
print(f'Columnas: {list(df.columns)}')
# Out:
# ==================================================
# CARGANDO DATOS
# ==================================================
# Archivo: C:\Users\basti\Desktop\guia 3\ProjectoDeportes\data\deportistas.csv
# Registros cargados: 2280
# Columnas: ['nombre', 'deporte', 'edad', 'peso_kg', 'altura_cm', 'frecuencia_cardiaca_bpm', 'horas_entrenamiento_semana', 'rendimiento_score', 'posicion']

# %%
# 1. Exploracion inicial del dataset
print('\n' + '=' * 50)
print('EXPLORACION INICIAL')
print('=' * 50)

print('\nPrimeras 10 filas:')
display(df.head(10))

print('\nTipos de datos:')
display(df.dtypes.to_frame('dtype'))

print('\nValores nulos por columna:')
display(df.isnull().sum().to_frame('nulos'))

print(f'\nNumero de filas duplicadas: {df.duplicated().sum()}')

print('\nProblemas detectados en el dataset:')
print('1. Filas mal parseadas (valores concatenados en nombre y NaN en otras columnas).')
print('2. Inconsistencias en etiquetas de deporte (mayusculas, tildes y variantes).')
print('3. Valores faltantes en multiples columnas numericas y categoricas.')
print('4. Posibles outliers en peso_kg y horas_entrenamiento_semana.')
print('5. Filas duplicadas.')
# Out:
# ==================================================
# EXPLORACION INICIAL
# ==================================================
#
# Primeras 10 filas:
#                                               nombre     deporte  edad  \
# 0  Tomás Gutiérrez,fútbol,28.0,"56,5",201.0,47.0,...         NaN   NaN
# 1                                       Paola Romero  Atletismo   42.0
# 2  Matías Silva,baloncesto,25.0,76.7,177.0,74.0,"...         NaN   NaN
# 3                                   Rodrigo Sandoval       Boxeo  18.0
# 4  Fernanda Jiménez,FUTBOL,19.0,68.6,199.0,53.0,"...         NaN   NaN
# 5                                       Diego Torres    natacion  44.0
# 6  Sebastián Rojas,NATACIÓN,25.0,102.6,183.0,57.0...         NaN   NaN
# 7  Alicia Campos,ATLETISMO,20.0,77.1,196.0,75.0,"...         NaN   NaN
# 8                                      Catalina Mora    Voleibol  29.0
# 9                                    Isabella Castro       Tenis  37.0
#
#    peso_kg  altura_cm  frecuencia_cardiaca_bpm  horas_entrenamiento_semana  \
# 0      NaN        NaN                      NaN                         NaN
# 1     88.7      185.0                     66.0                         NaN
# 2      NaN        NaN                      NaN                         NaN
# 3     58.7      163.0                     70.0                         NaN
# 4      NaN        NaN                      NaN                         NaN
# 5     93.6      197.0                      NaN                        23.7
# 6      NaN        NaN                      NaN                         NaN
# 7      NaN        NaN                      NaN                         NaN
# 8     73.7      183.0                     55.0                        24.0
# 9     68.1      187.0                     76.0                        12.8
#
#    rendimiento_score   posicion
# 0                NaN        NaN
# 1               7.75    nadador
# 2                NaN        NaN
# 3               5.42  delantero
# 4                NaN        NaN
# 5               4.14    defensa
# 6                NaN        NaN
# 7                NaN        NaN
# 8               9.76  DELANTERO
# 9               6.75    Defensa
# Tipos de datos:
#                               dtype
# nombre                       object
# deporte                      object
# edad                        float64
# peso_kg                     float64
# altura_cm                   float64
# frecuencia_cardiaca_bpm     float64
# horas_entrenamiento_semana  float64
# rendimiento_score           float64
# posicion                     object
# Valores nulos por columna:
#                             nulos
# nombre                          0
# deporte                      1017
# edad                         1069
# peso_kg                      1122
# altura_cm                    1079
# frecuencia_cardiaca_bpm      1073
# horas_entrenamiento_semana   1098
# rendimiento_score            1056
# posicion                     1148
# Numero de filas duplicadas: 80
#
# Problemas detectados en el dataset:
# 1. Filas mal parseadas (valores concatenados en nombre y NaN en otras columnas).
# 2. Inconsistencias en etiquetas de deporte (mayusculas, tildes y variantes).
# 3. Valores faltantes en multiples columnas numericas y categoricas.
# 4. Posibles outliers en peso_kg y horas_entrenamiento_semana.
# 5. Filas duplicadas.

# %%
# 2. Limpieza de datos
print('\n' + '=' * 50)
print('LIMPIEZA DE DATOS')
print('=' * 50)

df_limpio = limpiar_deportistas(df)
print(f'Registros despues de limpieza: {len(df_limpio)}')

print('\nEstadisticas despues de limpieza:')
display(df_limpio.describe(include='all'))
# Out:
# ==================================================
# LIMPIEZA DE DATOS
# ==================================================
# Registros despues de limpieza: 1916
#
# Estadisticas despues de limpieza:
#                     nombre   deporte         edad      peso_kg    altura_cm  \
# count                 1916      1916  1916.000000  1916.000000  1916.000000
# unique                  50         9          NaN          NaN          NaN
# top     Enrique Valenzuela  NATACION          NaN          NaN          NaN
# freq                    50       352          NaN          NaN          NaN
# mean                   NaN       NaN    31.162074    79.934395   179.573687
# std                    NaN       NaN    15.392731    14.573115    20.649050
# min                    NaN       NaN     3.000000    55.000000    25.000000
# 25%                    NaN       NaN    23.000000    67.400000   169.750000
# 50%                    NaN       NaN    31.000000    80.000000   179.561709
# 75%                    NaN       NaN    38.000000    92.600000   191.000000
# max                    NaN       NaN   200.000000   105.000000   300.000000
#
#         frecuencia_cardiaca_bpm  horas_entrenamiento_semana  \
# count               1916.000000                 1916.000000
# unique                      NaN                         NaN
# top                         NaN                         NaN
# freq                        NaN                         NaN
# mean                  69.581692                   13.782829
# std                   29.497639                    6.461295
# min                    5.000000                    0.100000
# 25%                   57.000000                    8.300000
# 50%                   69.000000                   13.600000
# 75%                   79.000000                   19.300000
# max                  350.000000                   25.000000
#
#         rendimiento_score posicion
# count         1916.000000     1813
# unique                NaN        9
# top                   NaN  DEFENSA
# freq                  NaN      252
# mean             5.551278      NaN
# std              2.849382      NaN
# min             -5.000000      NaN
# 25%              3.297500      NaN
# 50%              5.552869      NaN
# 75%              7.720000      NaN
# max             20.000000      NaN

# %% [markdown]
# Datos  Limpios:

# %%
df_limpio
# Out:
#                 nombre     deporte       edad  peso_kg  altura_cm  \
# 0      Tomás Gutiérrez      FUTBOL  28.000000     56.5      201.0
# 2         Matías Silva  BALONCESTO  25.000000     76.7      177.0
# 4     Fernanda Jiménez      FUTBOL  19.000000     68.6      199.0
# 5         Diego Torres    NATACION  44.000000     93.6      197.0
# 6      Sebastián Rojas    NATACION  25.000000    102.6      183.0
# ...                ...         ...        ...      ...        ...
# 2272     Mónica Ortega       BOXEO  31.129301     75.6      193.0
# 2275  Javiera Espinoza    NATACION  29.000000    101.7      168.0
# 2276   Isabella Castro      FUTBOL  20.000000     66.0      171.0
# 2278     Carolina Ríos       TENIS  21.000000     90.9      184.0
# 2279  Fernanda Jiménez  BALONCESTO  28.000000     68.4      175.0
#
#       frecuencia_cardiaca_bpm  horas_entrenamiento_semana  rendimiento_score  \
# 0                   47.000000                        16.8               8.06
# 2                   74.000000                        18.1               4.66
# 4                   53.000000                        23.7               8.22
# 5                   69.500263                        23.7               4.14
# 6                   57.000000                        15.6               7.16
# ...                       ...                         ...                ...
# 2272                46.000000                        11.1               5.74
# 2275                88.000000                        12.5               6.31
# 2276                80.000000                        10.9               6.53
# 2278                84.000000                        12.7               7.81
# 2279                85.000000                        24.3               3.44
#
#            posicion
# 0     MEDIOCAMPISTA
# 2           NADADOR
# 4          CICLISTA
# 5           DEFENSA
# 6           PORTERO
# ...             ...
# 2272       CORREDOR
# 2275        DEFENSA
# 2276        PORTERO
# 2278        DEFENSA
# 2279  MEDIOCAMPISTA
#
# [1916 rows x 9 columns]

# %%
# 3. Analisis de datos
print('\n' + '=' * 50)
print('ANALISIS DE DATOS')
print('=' * 50)

resumen = Resumen_datos(df_limpio)
print(f"Total de deportistas: {resumen['total_deportistas']}")
print(f"Promedio de rendimiento: {resumen['promedio_rendimiento']:.2f}")
print(f"Edad promedio: {resumen['edad_promedio']:.2f}")

print('\nPromedio de rendimiento por deporte:')
analisis_por_deporte = Promedio_por_deporte(df_limpio)
display(analisis_por_deporte.sort_values('promedio_rendimiento', ascending=False))

destacados = Deportistas_destacados(df_limpio, umbral=7.0)
print(f"\nNumero de deportistas destacados (rendimiento > 7.0): {len(destacados)}")
if len(destacados) > 0:
    print('\nTop 5 deportistas destacados:')
    display(destacados[['nombre', 'deporte', 'rendimiento_score']].head(5))
# Out:
# ==================================================
# ANALISIS DE DATOS
# ==================================================
# Total de deportistas: 1916.0
# Promedio de rendimiento: 5.55
# Edad promedio: 31.16
#
# Promedio de rendimiento por deporte:
#       deporte  promedio_rendimiento
# 2       BOXEO              5.944518
# 0   ATLETISMO              5.925956
# 7       TENIS              5.774218
# 6       RUGBY              5.678661
# 8    VOLEIBOL              5.626760
# 3    CICLISMO              5.456275
# 5    NATACION              5.441681
# 4      FUTBOL              5.261208
# 1  BALONCESTO              5.185505
# Numero de deportistas destacados (rendimiento > 7.0): 631
#
# Top 5 deportistas destacados:
#                nombre   deporte  rendimiento_score
# 0     Tomás Gutiérrez    FUTBOL               8.06
# 4    Fernanda Jiménez    FUTBOL               8.22
# 6     Sebastián Rojas  NATACION               7.16
# 8       Catalina Mora  VOLEIBOL               9.76
# 11  Valentina Ramírez     TENIS               8.55

# %%
# 4. Exportar resultados
print('\n' + '=' * 50)
print('EXPORTANDO RESULTADOS')
print('=' * 50)

os.makedirs(base_path / 'outputs', exist_ok=True)


df_limpio.to_csv(base_path / 'outputs' / 'deportistas_limpios.csv', index=False)
print('Datos limpios guardados en outputs/deportistas_limpios.csv')

analisis_por_deporte.to_csv(base_path / 'outputs' / 'analisis_por_deporte.csv', index=False)
print('Analisis por deporte guardado en outputs/analisis_por_deporte.csv')
# Out:
# ==================================================
# EXPORTANDO RESULTADOS
# ==================================================
# Datos limpios guardados en outputs/deportistas_limpios.csv
# Analisis por deporte guardado en outputs/analisis_por_deporte.csv

# %%
print('\n' + '=' * 50)
print('PROCESO COMPLETADO EXITOSAMENTE')
print('=' * 50)
# Out:
# ==================================================
# PROCESO COMPLETADO EXITOSAMENTE
# ==================================================
